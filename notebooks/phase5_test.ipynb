# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8")

# %%
def load_split(split):
    X = np.load(f"dataset/{split}/X.npy")
    y = np.load(f"dataset/{split}/y.npy")
    meta = pd.read_csv(f"dataset/{split}/meta.csv")
    return X, y, meta

X_train, y_train, meta_train = load_split("train")
X_val, y_val, meta_val = load_split("val")
X_test, y_test, meta_test = load_split("test")

X_train.shape, y_train.shape, meta_train.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 7
#       4     meta = pd.read_csv(f"dataset/{split}/meta.csv")
#       5     return X, y, meta
# ----> 7 X_train, y_train, meta_train = load_split("train")
#       8 X_val, y_val, meta_val = load_split("val")
#       9 X_test, y_test, meta_test = load_split("test")
#
# Cell In[2], line 2, in load_split(split)
#       1 def load_split(split):
# ----> 2     X = np.load(f"dataset/{split}/X.npy")
#       3     y = np.load(f"dataset/{split}/y.npy")
#       4     meta = pd.read_csv(f"dataset/{split}/meta.csv")
#
# File d:\IITMStudy\MajorProjects\industrial-predictive-maintenance-simulator\.venv\Lib\site-packages\numpy\lib\_npyio_impl.py:454, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     452     own_fid = False
#     453 else:
# ...
